# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# *An integer (8) and floating point number (2.5) are involved. The resulting data type is an integer (20).*

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# *Two integers (9 and 2) are involved. The resulting data type is a floating point number (4.5).*

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# *One floating point number (1.5) and three integers (2,7, and 3) are involved. The resulting data point is boolean (False).*

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4

# %% [markdown]
# *The multiplication expressions will be evaluated, followed by the addition expressions.*

# %%
5 - 2 * 3 ** 4

# %% [markdown]
# *The exponentiation expression will be evaluated, followed by the multiplication expression, and finally the subtraction expression.*

# %%
(5 - 2) * 3 ** 4

# %% [markdown]
# *The exponentiation expression will be evaluated, followed by the bracketed subtraction expression, and finally the multiplication expression.*

# %%
5 + 2 >= 3 * 4

# %% [markdown]
# *The multiplication expression will be evaluated, followed by the addition expression, and finally the greater than or equal to expression.*

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# *No error.*

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_1140/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# *This results in a syntax error as this is a compound assignment operator, and you can not assign a new value to a distinct number like 84.*

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# *No error.*

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_1140/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# *This is an error as you can not assign something like weight into a calculated value like 5 times 3.*

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# *No error.*

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

if value == str(value):
    print("The value is valid).")
else:
    print("The value must not a string.")
# Out:
# The value must not a string.

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1140/2963248189.py in <cell line: 0>()
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# *This is an index error. This list has 3 elements (1, 2 and 3). However, python starts counting at 0. By asking to print 3, we are asking to print the fourth element, which does not exist.*

# %%
fullName = "Taylor Swift"
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1140/3996353418.py in <cell line: 0>()
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_name)
#
# NameError: name 'full_name' is not defined

# %% [markdown]
# *This is a name error. We defined fullName, then ask for full_name, which is considered a different and undefined variable (it is not spelled or formatted in the same way).*

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1140/1647341539.py in <cell line: 0>()
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# *This is a type error as here, 2 and 4 are integers, but '2' is a string. You can not add integers to strings.*

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_m(km):
  """ this function converts a distance from kilometers to miles.
  Parameters: distance in kilometers (float)
  Returns: distance in miles (float)
  """
  return km / 1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# *The value 3 is printed.*

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output here
    >>> repeat('yesnomaybe', 3)
    # yesnomaybeyesnomaybeyesnomaybe
    '''

    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    only_numbers = number.replace('(', '')

    return only_numbers.startswith('416')
